# %%
# %%bash
# cd /content
#
# if [ ! -d cuda-kernel-lab-codex/.git ]; then
#   git clone https://github.com/abbudjoe/cuda-kernel-lab-codex.git
# else
#   cd cuda-kernel-lab-codex
#   git pull --ff-only
# fi
#
# cd /content/cuda-kernel-lab-codex
# git status --short --branch
# git rev-parse --short HEAD

# %%
# %%bash
# cd /content/cuda-kernel-lab-codex
#
# rm -rf build
# cmake -S . -B build -DCMAKE_BUILD_TYPE=Release -DCMAKE_CUDA_ARCHITECTURES=75
# cmake --build build -j

# %%
# %%bash
# nvidia-smi
# nvcc --version
# cmake --version
# python3 --version
